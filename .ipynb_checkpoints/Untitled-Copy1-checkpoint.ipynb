# %%
import scvelo as scv
import scanpy as sc
import numpy as np

# %%
scv.settings.verbosity = 3  
scv.settings.presenter_view = True 
scv.set_figure_params('scvelo')

# %%
adata1 = scv.datasets.pancreas()

# %%
adata1
# Out:
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced'
#     obsp: 'distances', 'connectivities'

# %%
scv.pp.filter_genes(adata1, min_shared_counts=20)
scv.pp.normalize_per_cell(adata1)
scv.pp.filter_genes_dispersion(adata1, n_top_genes=2000)
scv.pp.log1p(adata1)
scv.pp.pca(adata1)
sc.pl.pca(adata1, color = "clusters")
# scv.pp.moments(adata1, n_pcs=30, n_neighbors=20)
# Out:
# Filtered out 20801 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.

# %%
adata1.uns['neighbors']
# Out:
# OverloadedDict, wrapping:
# 	{'params': {'method': array(['umap'], dtype=object), 'n_neighbors': array([15])}}
# With overloaded keys:
# 	['connectivities', 'distances'].

# %%
scv.pp.moments(adata1, n_neighbors =50)
adata1.uns['neighbors']
# Out:
# computing neighbors
# OMP: Info #273: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#     finished (0:00:05) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# OverloadedDict, wrapping:
# 	{'connectivities_key': 'connectivities', 'distances_key': 'distances', 'indices': array([[   0,  889, 3051, ..., 1479, 2456,  324],
#        [   1, 1807,  950, ..., 1667, 3468,  937],
#        [   2, 1215, 3500, ..., 1827, 1068, 1177],
#        ...,
#        [3693, 1591,  743, ..., 2589,  455,    9],
#        [3694, 2172, 3446, ..., 1624, 1242, 1664],
#        [3695, 2764, 2978, ..., 3103, 2868, 3641]]), 'params': {'n_neighbors': 50, 'method': 'umap', 'metric': 'euclidean', 'n_pcs': None, 'use_rep': 'X_pca'}}
# With overloaded keys:
# 	['connectivities', 'distances'].

# %%
adata1.uns['neighbors']['params']
# Out:
# {'n_neighbors': 50,
#  'method': 'umap',
#  'metric': 'euclidean',
#  'n_pcs': None,
#  'use_rep': 'X_pca'}

# %%
scv.tl.recover_dynamics(adata1,n_jobs=10)
# Out:
# recovering dynamics (using 10/12 cores)
# WARNING: Unable to create progress bar. Consider installing `tqdm` as `pip install tqdm` and `ipywidgets` as `pip install ipywidgets`,
# or disable the progress bar using `show_progress_bar=False`.
#     finished (0:02:55) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)

# %%
scv.tl.velocity(adata1, mode="deterministic")
# Out:
# computing velocities
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 scv.tl.velocity(adata1, mode="steady")
#
# File ~/miniconda3/lib/python3.8/site-packages/scvelo/tools/velocity.py:438, in velocity(data, vkey, mode, fit_offset, fit_offset2, filter_genes, groups, groupby, groups_for_fit, constrain_ratio, use_raw, use_latent_time, perc, min_r2, min_likelihood, r2_adjusted, use_highly_variable, diff_kinetics, copy, **kwargs)
#     435             adata._inplace_subset_var(velo._velocity_genes)
#     437 else:
# --> 438     raise ValueError(
#     439         "Mode can only be one of these: deterministic, stochastic or dynamical."
#     440     )
#     442 if f"{vkey}_genes" in adata.var.keys() and np.sum(adata.var[f"{vkey}_genes"]) < 10:
#     443     logg.warn(
#     444         "Too few genes are selected as velocity genes. "
#     445         "Consider setting a lower threshold for min_r2 or min_likelihood."
#     446     )
#
# ValueError: Mode can only be one of these: deterministic, stochastic or dynamical.

# %%
scv.tl.velocity_graph(adata1)

# %%
scv.pl.scatter(adata1, basis=['Abcc8','Sulf2','Top2a'],color='clusters', use_raw=False)

# %%
adata1

# %%
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=0.1)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=0.3)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=0.5)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=1)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.__version__

# %%
# If we use all 50 PCs
scv.pp.moments(adata1, n_neighbors =50)
adata1.uns['neighbors']
scv.tl.recover_dynamics(adata1,n_jobs=10)
scv.tl.velocity(adata1, mode="deterministic")
scv.tl.velocity_graph(adata1)
scv.pl.scatter(adata1, basis=['Abcc8','Sulf2','Top2a'],color='clusters', use_raw=False)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=0.1)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=0.5)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=1)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=0.5)
scv.pl.velocity_embedding_stream(adata1, basis='umap')

# %%
scv.tl.umap(adata1, min_dist=0.5)
scv.pl.velocity_embedding_stream(adata1, basis='umap')
